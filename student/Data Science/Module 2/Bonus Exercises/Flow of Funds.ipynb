# %% [markdown]
# # Investor - Flow of Funds - US
# Introduction:
#
# Special thanks to: https://github.com/rgrp for sharing the dataset.

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this address.
#
# ### Step 3. Assign it to a variable called

# %%
flows = pd.read_csv('https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv')
flows.head()
# Out:
#          Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0  2022-07-06         10167              NaN          3058     NaN
# 1  2022-07-13          7409              NaN          2808     NaN
# 2  2022-07-20          3468              NaN           102     NaN
# 3  2022-07-27         14213              NaN          9667     NaN
# 4  2022-08-03          9786              NaN          4016     NaN
#
#    Total Bond  Taxable Bond  Municipal Bond  Total
# 0         842           NaN            2216    NaN
# 1        2067           NaN             741    NaN
# 2        -417           NaN             519    NaN
# 3        8598           NaN            1069    NaN
# 4        3079           NaN             937    NaN

# %% [markdown]
# ### Step 4. What is the frequency of the dataset?

# %%
flows['Date'] = pd.to_datetime(flows['Date'])

flows = flows.set_index('Date')

print(flows.index.freq)
# Out:
# None

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
flows.head()
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2022-07-06         10167              NaN          3058     NaN         842
# 2022-07-13          7409              NaN          2808     NaN        2067
# 2022-07-20          3468              NaN           102     NaN        -417
# 2022-07-27         14213              NaN          9667     NaN        8598
# 2022-08-03          9786              NaN          4016     NaN        3079
#
#             Taxable Bond  Municipal Bond  Total
# Date
# 2022-07-06           NaN            2216    NaN
# 2022-07-13           NaN             741    NaN
# 2022-07-20           NaN             519    NaN
# 2022-07-27           NaN            1069    NaN
# 2022-08-03           NaN             937    NaN

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
type(flows.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
flows.index
# Out:
# DatetimeIndex(['2022-07-06', '2022-07-13', '2022-07-20', '2022-07-27',
#                '2022-08-03', '2022-08-10', '2022-08-17', '2022-08-24',
#                '2022-08-31', '2022-09-07',
#                ...
#                '2025-10-01', '2025-10-08', '2026-02-04', '2026-02-11',
#                '2026-02-18', '2026-02-25', '2026-03-04', '2026-03-11',
#                '2026-03-18', '2026-03-25'],
#               dtype='datetime64[ns]', name='Date', length=118, freq=None)

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %%
import datetime
flows.index = pd.to_datetime(flows.index)
type(flows.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ### Step 8. Change the frequency to monthly, sum the values and assign it to monthly.

# %%
monthly = flows.resample('ME').sum(min_count=1)

monthly
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2022-07-31       35257.0              NaN       15635.0     NaN     11090.0
# 2022-08-31       48596.0              NaN       32348.0     NaN     33705.0
# 2022-09-30       13775.0              NaN       10324.0     NaN     11629.0
# 2022-10-31       82879.0              NaN       55644.0     NaN     47435.0
# 2022-11-30       82731.0              NaN       54314.0     NaN     37348.0
# 2022-12-31       40451.0              NaN       29124.0     NaN     18273.0
# 2023-01-31       34891.0              NaN        7849.0     NaN     -9996.0
# 2023-02-28       13284.0              NaN       16508.0     NaN      6243.0
# 2023-03-31       28861.0              NaN        3713.0     NaN      2500.0
# 2023-04-30       39723.0              NaN       19058.0     NaN     14426.0
# 2023-05-31       23789.0              NaN        6377.0     NaN      2020.0
# ...

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
monthly = monthly.dropna()

monthly
# Out:
# Empty DataFrame
# Columns: [Total Equity, Domestic Equity, World Equity, Hybrid, Total Bond, Taxable Bond, Municipal Bond, Total]
# Index: []

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %%
flows.resample('YE').sum()
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2022-12-31        303689              0.0        197389     0.0      159480
# 2023-12-31        577223              0.0        384006     0.0      301790
# 2024-12-31        501341              0.0        362632     0.0      312430
# 2025-12-31        204465              0.0        126778     0.0       90915
# 2026-12-31        296299              0.0        177177     0.0       85818
#
#             Taxable Bond  Municipal Bond  Total
# Date
# 2022-12-31           0.0           37908    0.0
# 2023-12-31           0.0           82214    0.0
# 2024-12-31           0.0           50200    0.0
# 2025-12-31           0.0           35862    0.0
# 2026-12-31           0.0           91358    0.0

# %% [markdown]
# ## BONUS: Create your own question and answer it.

# %% [markdown]
# ### Who is the genius student who solved this assignment?

# %%
print('Mona')
# Out:
# Mona

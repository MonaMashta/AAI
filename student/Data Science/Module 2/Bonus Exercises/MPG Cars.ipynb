# %% [markdown]
# Name: Mona Mashtaa

# %% [markdown]
# # MPG Cars

# %% [markdown]
# Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)

# %% [markdown]
# ## Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ## Step 2. Import the first dataset cars1 and cars2.
#
# ## Step 3. Assign each to a variable called cars1 and cars2

# %%
car1 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv')
car2 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv')

# %% [markdown]
# ## Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
car1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %%
# if it is include the null valu or not
car1.isnull().sum()
# Out:
# mpg               0
# cylinders         0
# displacement      0
# horsepower        0
# weight            0
# acceleration      0
# model             0
# origin            0
# car               0
# Unnamed: 9      198
# Unnamed: 10     198
# Unnamed: 11     198
# Unnamed: 12     198
# Unnamed: 13     198
# dtype: int64

# %%
car1= car1.dropna()

# %%
car1.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model           0
# origin          0
# car             0
# Unnamed: 9      0
# Unnamed: 10     0
# Unnamed: 11     0
# Unnamed: 12     0
# Unnamed: 13     0
# dtype: int64

# %%
car2.head()
car2.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model           0
# origin          0
# car             0
# dtype: int64

# %% [markdown]
# ## Step 5. What is the number of observations in each dataset?

# %%
car1.shape[0]
# Out:
# 0

# %%
car2.shape[0]
# Out:
# 200

# %% [markdown]
# ## Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
car1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
car2.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car'],
#       dtype='object')

# %% [markdown]
# it is have same columns, so that's easy to join

# %%
cars = pd.concat([car1, car2], axis=1)
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'mpg', 'cylinders',
#        'displacement', 'horsepower', 'weight', 'acceleration', 'model',
#        'origin', 'car'],
#       dtype='object')

# %% [markdown]
# ## Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
import numpy as np
cars['owners'] = np.random.randint(15000, 73001, size=len(cars))

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'mpg', 'cylinders',
#        'displacement', 'horsepower', 'weight', 'acceleration', 'model',
#        'origin', 'car', 'owners'],
#       dtype='object')

# %% [markdown]
# ## Step 8. Add the column owners to cars

# %%
cars.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0  NaN        NaN           NaN         NaN     NaN           NaN    NaN
# 1  NaN        NaN           NaN         NaN     NaN           NaN    NaN
# 2  NaN        NaN           NaN         NaN     NaN           NaN    NaN
# 3  NaN        NaN           NaN         NaN     NaN           NaN    NaN
# 4  NaN        NaN           NaN         NaN     NaN           NaN    NaN
#
#   origin  car  Unnamed: 9  ...   mpg  cylinders  displacement  horsepower  \
# 0    NaN  NaN         NaN  ...  33.0          4            91          53
# 1    NaN  NaN         NaN  ...  20.0          6           225         100
# 2    NaN  NaN         NaN  ...  18.0          6           250          78
# 3    NaN  NaN         NaN  ...  18.5          6           250         110
# 4    NaN  NaN         NaN  ...  17.5          6           258          95
#
#    weight  acceleration  model origin                 car  owners
# 0    1795          17.4     76      3         honda civic   29181
# 1    3651          17.7     76      1      dodge aspen se   44503
# 2    3574          21.0     76      1   ford granada ghia   15132
# 3    3645          16.2     76      1  pontiac ventura sj   64951
# 4    3193          17.8     76      1       amc pacer d/l   41347
#
# [5 rows x 24 columns]

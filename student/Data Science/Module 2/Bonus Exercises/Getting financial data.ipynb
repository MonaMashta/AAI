# %% [markdown]
# # Getting Financial Data - Pandas Datareader
# Introduction:
#
# This time you will get data from a website.

# %%
# !pip install pandas-datareader
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas-datareader in /home/mona/.local/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: lxml in /home/mona/.local/lib/python3.10/site-packages (from pandas-datareader) (6.0.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/lib/python3/dist-packages (from pandas-datareader) (2.25.1)
# Requirement already satisfied: pandas>=0.23 in /home/mona/.local/lib/python3.10/site-packages (from pandas-datareader) (2.3.3)
# Requirement already satisfied: tzdata>=2022.7 in /home/mona/.local/lib/python3.10/site-packages (from pandas>=0.23->pandas-datareader) (2025.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/mona/.local/lib/python3.10/site-packages (from pandas>=0.23->pandas-datareader) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mona/.local/lib/python3.10/site-packages (from pandas>=0.23->pandas-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.23->pandas-datareader) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting yfinance
#   Downloading yfinance-1.2.2-py2.py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 KB 557.9 kB/s eta 0:00:00a 0:00:01
# Collecting websockets>=13.0
#   Downloading websockets-16.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 KB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting requests>=2.31
#   Downloading requests-2.33.1-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 KB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.5 in /home/mona/.local/lib/python3.10/site-packages (from yfinance) (2.2.6)
# Collecting peewee>=3.16.2
#   Downloading peewee-4.0.4-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 KB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3.0 in /home/mona/.local/lib/python3.10/site-packages (from yfinance) (2.3.3)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pytz>=2022.5
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 KB 4.3 MB/s eta 0:00:00a 0:00:01
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.4.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.2/120.2 KB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.0.0 in /home/mona/.local/lib/python3.10/site-packages (from yfinance) (4.9.4)
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 KB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.19.0 in /home/mona/.local/lib/python3.10/site-packages (from yfinance) (7.34.0)
# Collecting curl_cffi>=0.15
#   Downloading curl_cffi-0.15.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 15.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/mona/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/lib/python3/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Collecting cffi>=2.0.0
#   Downloading cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 KB 18.9 MB/s eta 0:00:00
# Collecting certifi>=2024.2.2
#   Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 KB 7.2 MB/s eta 0:00:00
# Collecting rich
#   Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 KB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.7 in /home/mona/.local/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mona/.local/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/lib/python3/dist-packages (from requests>=2.31->yfinance) (1.26.5)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.9/216.9 KB 7.7 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-3.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 KB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.20.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.0 MB/s eta 0:00:00a 0:00:01
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 KB 5.0 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15550 sha256=7d31346e5fb02b3301981e099c46cd7888bc0efa0b0368806d90d6c244b1274b
#   Stored in directory: /home/mona/.cache/pip/wheels/e9/25/85/25d2e1cfc0ece64b930b16972f7e4cc3599c43b531f1eba06d
# Successfully built multitasking
# Installing collected packages: pytz, peewee, multitasking, websockets, pygments, pycparser, mdurl, frozendict, charset_normalizer, certifi, beautifulsoup4, requests, markdown-it-py, cffi, rich, curl_cffi, yfinance
# Successfully installed beautifulsoup4-4.14.3 certifi-2026.2.25 cffi-2.0.0 charset_normalizer-3.4.7 curl_cffi-0.15.0 frozendict-2.4.7 markdown-it-py-4.0.0 mdurl-0.1.2 multitasking-0.0.12 peewee-4.0.4 pycparser-3.0 pygments-2.20.0 pytz-2026.1.post1 requests-2.33.1 rich-15.0.0 websockets-16.0 yfinance-1.2.2

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# package to extract data from various Internet sources into a DataFrame
# make sure you have it installed
import pandas_datareader.data as web

# package for dates
import datetime as dt

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is).

# %%
start = dt.datetime(2015, 1, 1)
end = dt.datetime.today()

start
# Out:
# datetime.datetime(2015, 1, 1, 0, 0)

# %% [markdown]
# # M1.Ex4: Modeling Non-linear Patterns

# %% [markdown]
# - Run: [**Open In Colab**](https://colab.research.google.com/github/HassanAlgoz/B5/blob/main/content/W3/M1/exercises/ex4_non-linear.ipynb)
# - Raw Dataset: [bmi_and_life_expectancy.csv](https://raw.githubusercontent.com/HassanAlgoz/B5/main/content/datasets/bmi_and_life_expectancy.csv)

# %%
import pandas as pd
import sklearn

# %% [markdown]
# ### Step 1. Load the data

# %%
df =pd.read_csv("/home/mona/Downloads/SAD/AAI/content/datasets/bmi_and_life_expectancy.csv").head()
df.head()
# Out:
#        Country  Life expectancy       BMI
# 0  Afghanistan             52.8  20.62058
# 1      Albania             76.8  26.44657
# 2      Algeria             75.5  24.59620
# 3      Andorra             84.6  27.63048
# 4       Angola             56.7  22.25083

# %% [markdown]
# ### Step 2.a Assign variables `X` to the features and `y` to the target

# %%
X= df[['BMI']]
y=df['Life expectancy']

# %% [markdown]
# ### Step 2.b print the type of each

# %%
X.dtypes
# Out:
# BMI    float64
# dtype: object

# %%
y.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 2.c identify whether the target is categorical or numerical & whether the task is regression or classification

# %% [markdown]
# The target is Numerical (specifically, Continuous) because Life expectancy is a measurement of time (years). It can be any value within a range.

# %% [markdown]
# ### Step 3. Identify the number of samples and columns of both the data matrix and the target

# %%
# Samples (rows)
n_samples_X = X.shape[0]
n_samples_y = y.shape[0]

# Columns (features)
n_features_X = X.shape[1]

print(f"Data Matrix (X): {n_samples_X} samples and {n_features_X} columns")
print(f"Target vector (y): {n_samples_y} samples and 1 column")
# Out:
# Data Matrix (X): 5 samples and 1 columns
# Target vector (y): 5 samples and 1 column

# %% [markdown]
# ### Step 4. Summarize the distribution of the data (min, max, median, mean, and standard deviation)

# %%
X.describe()
# Out:
#              BMI
# count   5.000000
# mean   24.308932
# std     2.895014
# min    20.620580
# 25%    22.250830
# 50%    24.596200
# 75%    26.446570
# max    27.630480

# %% [markdown]
# ### Step 5. Plot the feature vs the target

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['BMI'], y=df['Life expectancy'])

# Add labels and title
plt.xlabel('BMI')
plt.ylabel('Life Expectancy (Years)')
plt.title('Step 5: BMI vs Life Expectancy')
# Out:
# /home/mona/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Text(0.5, 1.0, 'Step 5: BMI vs Life Expectancy')

# %% [markdown]
# ### Step 6. What is the relationship between the feature and the target? (increasing or decreasing or none)

# %% [markdown]
# The relationship between BMI and Life Expectancy is Increasing.
# If you look at your scatter plot from left to right, the "cloud" of dots moves upward.

# %% [markdown]
# ### Step 7. Make two modeling techniques
#
# First model is just a Linear Regression model: `from sklearn.linear_model import LinearRegression`
#
# Second model: Use one of the previously mentioned methods to model a non-linear relationship
#
# 1. `from sklearn.tree import DecisionTreeRegressor`
# 2. or `from sklearn.preprocessing import PolynomialFeatures`

# %% [markdown]
# ### Step 8. Split the dataset into train and test sets

# %% [markdown]
# ### Step 9. Train both models on the training set

# %% [markdown]
# ### Step 10. Evaluate and compare which of the two models score better on the `train` set

# %% [markdown]
# ### Step 11. Evaluate and compare which of the two models score better on the `test` set
